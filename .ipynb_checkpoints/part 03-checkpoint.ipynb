# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import Text
from sqlalchemy.orm import sessionmaker
from sqlalchemy_utils import database_exists, create_database
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus as urlquote

from sqlalchemy import create_engine, Column, String, Float, Integer
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
title_basics_df = pd.read_csv(r'\Users\lidiv\project03\project3\Data/title_basic_filtered.csv.gz', compression='gzip', low_memory=False)
title_ratings_df =  pd.read_csv(r'\Users\lidiv\project03\project3\Data/title_rating_filtered.csv.gz', compression='gzip', low_memory=False)
tmdb_data_df = pd.read_csv(r'\Users\lidiv\project03\project3\tmdb_results_combined.csv.gz', compression='gzip', low_memory=False)

# %%
import json
with open('/Users/lidiv/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
connection = f"mysql+mysqlconnector://{login['username']}:{urlquote(login['password'])}@localhost:3306/movie"
engine = create_engine(connection)

# %%
## Check if database exists, if not, create it
if database_exists(connection):
    print('It exists!')
else:
    create_database(connection)
    print('Database created!')
# Out:
# It exists!

# %%
# Normalize genres
title_basics_df['genres_split'] = title_basics_df['genres'].str.split(', ')

# %%
exploded_genres = title_basics_df.explode('genres_split')
exploded_genres
# Out:
#            tconst titleType  \
# 0       tt0011801     movie
# 1       tt0015414     movie
# 2       tt0035423     movie
# 3       tt0062336     movie
# 4       tt0068865     movie
# ...           ...       ...
# 187792  tt9916362     movie
# 187793  tt9916428     movie
# 187794  tt9916538     movie
# 187795  tt9916706     movie
# 187796  tt9916730     movie
#
#                                              primaryTitle  \
# 0                                        Tötet nicht mehr
# 1                                  La tierra de los toros
# 2                                          Kate & Leopold
# 3       The Tango of the Widower and Its Distorting Mi...
# 4                                     Lives of Performers
# ...                                                   ...
# 187792                                              Coven
# 187793                                The Secret of China
# 187794                                Kuambil Lagi Hatiku
# ...

# %%
# !pip install sqlalchemy sqlalchemy-utils
# !pip install mysql-connector-python

# %%
#unique_genres = sorted(exploded_genres['genres'].unique())

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
titles_genres= exploded_genres[['tconst', 'genres_split']].copy()
titles_genres.head()
# Out:
#       tconst            genres_split
# 0  tt0011801            Action,Crime
# 1  tt0015414                      \N
# 2  tt0035423  Comedy,Fantasy,Romance
# 3  tt0062336                   Drama
# 4  tt0068865                   Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Action,Adult': 1,
#  'Action,Adult,Crime': 2,
#  'Action,Adult,Drama': 3,
#  'Action,Adult,Sci-Fi': 4,
#  'Action,Adventure': 5,
#  'Action,Adventure,Animation': 6,
#  'Action,Adventure,Biography': 7,
#  'Action,Adventure,Comedy': 8,
#  'Action,Adventure,Crime': 9,
#  'Action,Adventure,Drama': 10,
#  'Action,Adventure,Family': 11,
#  'Action,Adventure,Fantasy': 12,
#  'Action,Adventure,History': 13,
#  'Action,Adventure,Horror': 14,
#  'Action,Adventure,Music': 15,
#  'Action,Adventure,Musical': 16,
#  'Action,Adventure,Mystery': 17,
#  'Action,Adventure,Romance': 18,
#  'Action,Adventure,Sci-Fi': 19,
#  'Action,Adventure,Sport': 20,
#  'Action,Adventure,Thriller': 21,
#  'Action,Adventure,War': 22,
#  'Action,Adventure,Western': 23,
#  'Action,Animation': 24,
#  'Action,Animation,Biography': 25,
#  'Action,Animation,Comedy': 26,
#  'Action,Animation,Crime': 27,
#  'Action,Animation,Drama': 28,
#  'Action,Animation,Family': 29,
#  'Action,Animation,Fantasy': 30,
# ...

# %%
## make new integer genre_id and drop string genres

title_basics_df['genre_id'] = title_basics_df['genres_split'].apply(lambda x: [genre_map[genre] for genre in x] if isinstance(x, list) else [])
title_basics_df = title_basics_df.drop(columns='genres_split')

# %%
genre_lookup = pd.DataFrame({'genre_name': genre_map.keys(),
                             'genre_ID': genre_map.values()})
genre_lookup.head()
# Out:
#             genre_name  genre_ID
# 0               Action         0
# 1         Action,Adult         1
# 2   Action,Adult,Crime         2
# 3   Action,Adult,Drama         3
# 4  Action,Adult,Sci-Fi         4

# %%
print(title_basics_df.columns)
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres', 'genre_id'],
#       dtype='object')

# %%
# Insert the DataFrame into the database
genre_lookup.to_sql('genres', engine, index=False, if_exists='replace')
# Out:
# 980

# %%
title_genres = title_basics_df[['tconst', 'genre_id']]
title_genres.head()
# Out:
#       tconst genre_id
# 0  tt0011801     [66]
# 1  tt0015414    [979]
# 2  tt0035423    [537]
# 3  tt0062336    [665]
# 4  tt0068865    [665]

# %%
title_genres_df= title_basics_df[['tconst', 'genre_id']].copy()
title_genres_df.head()
# Out:
#       tconst genre_id
# 0  tt0011801     [66]
# 1  tt0015414    [979]
# 2  tt0035423    [537]
# 3  tt0062336    [665]
# 4  tt0068865    [665]

# %%
# Flatten the 'genre_id' lists into a comma-separated string
title_genres_df['genre_id'] = title_genres_df['genre_id'].apply(lambda x: ','.join(map(str, x)))

# %%
# Insert the data into the 'title_genres' table
title_genres_df.to_sql('title_genres', engine, index=False, if_exists='replace')
# Out:
# 187797

# %%
title_basics_df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0011801     movie                                   Tötet nicht mehr
# 1  tt0015414     movie                             La tierra de los toros
# 2  tt0035423     movie                                     Kate & Leopold
# 3  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 4  tt0068865     movie                                Lives of Performers
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                           Tötet nicht mehr        0     2019.0      NaN
# 1                     La tierra de los toros        0     2000.0      NaN
# 2                             Kate & Leopold        0     2001.0      NaN
# 3  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 4                        Lives of Performers        0     2016.0      NaN
#
#   runtimeMinutes                  genres genre_id
# ...

# %%
# Insert the DataFrame into the database
exploded_genres.to_sql('title_basics', engine, index=False, if_exists='replace')
# Out:
# 187797

# %%
print(title_basics_df.columns)
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres', 'genre_id'],
#       dtype='object')

# %%
# Define a base class for declarative models
Base = declarative_base()

# %%
# Define your model class with a primary key and key length
class TitleBasics(Base):
    __tablename__ = 'title_basics'
    tconst = Column(String(20), primary_key=True)  # Here, '20' is the key length
    # Define other columns
    primaryTitle = Column(String)
    startYear = Column(Integer)
    runtimeMinutes =Column(Integer)
    originalTitle =Column(String)
    genres = Column(String)

# %%
title_ratings_df.to_sql('title_ratings', engine, index=False, if_exists='replace')
# Out:
# 117763

# %%
print(title_ratings_df.columns)
# Out:
# Index(['tconst', 'averageRating', 'numVotes'], dtype='object')

# %%
# Define the model class for title_ratings
class TitleRatings(Base):
    __tablename__ = 'title_ratings'
    tconst = Column(String(20), primary_key=True)  # Assuming '20' is the key length
    averageRating = Column(Float)
    numVotes = Column(Integer)

# %%
tmdb_data_df[['movie_id', 'budget', 'revenue', 'certification']].to_sql('tmdb_data', engine, index=False, if_exists='replace')
# Out:
# 8465

# %%
print(tmdb_data_df.columns)
# Out:
# Index(['movie_id', 'budget', 'revenue', 'certification'], dtype='object')

# %%
# Define your model class with a primary key and key length
class tmdb_data(Base):
    __tablename__ = 'tmdb_data'
    movie_id = Column(String(20), primary_key=True)  # Here, '20' is the key length
    # Define other columns
    budget = Column(Integer)
    revenue = Column(Integer)
    certification =Column(Float)

# %%
# Define the schema for the 'genres' table
create_genres_table = """
CREATE TABLE IF NOT EXISTS genres (
    tconst VARCHAR(255) PRIMARY KEY,
    genre TEXT
);
"""

# Execute the SQL command to create the table
engine.execute(create_genres_table)

# %%
# Execute SQL queries to show the first 5 rows of each table
tables = ['title_basics', 'title_ratings', 'title_genres', 'genres', 'tmdb_data']
for table in tables:
    result = engine.execute(f'SELECT * FROM {table} LIMIT 5')
    print(f'First 5 rows of {table}:')
    for row in result:
        print(row)
    print('\n')
# Out:
# First 5 rows of title_basics:
# ('tt0011801', 'movie', 'Tötet nicht mehr', 'Tötet nicht mehr', 0, 2019.0, None, '\\N', 'Action,Crime', 'Action,Crime')
# ('tt0015414', 'movie', 'La tierra de los toros', 'La tierra de los toros', 0, 2000.0, None, '60', '\\N', '\\N')
# ('tt0035423', 'movie', 'Kate & Leopold', 'Kate & Leopold', 0, 2001.0, None, '118', 'Comedy,Fantasy,Romance', 'Comedy,Fantasy,Romance')
# ('tt0062336', 'movie', 'The Tango of the Widower and Its Distorting Mirror', 'El tango del viudo y su espejo deformante', 0, 2020.0, None, '70', 'Drama', 'Drama')
# ('tt0068865', 'movie', 'Lives of Performers', 'Lives of Performers', 0, 2016.0, None, '90', 'Drama', 'Drama')
#
#
# First 5 rows of title_ratings:
# ('tt0015414', 5.2, 16)
# ('tt0035423', 6.4, 87565)
# ('tt0062336', 6.4, 180)
# ('tt0068865', 5.4, 74)
# ('tt0069049', 6.7, 7830)
#
#
# First 5 rows of title_genres:
# ('tt0011801', '66')
# ('tt0015414', '979')
# ('tt0035423', '537')
# ('tt0062336', '665')
# ('tt0068865', '665')
# ...

# %%
# Show all tables in the 'movies' database
result = engine.execute('SHOW TABLES')
print('Tables in the database:')
for row in result:
    print(row[0])
# Out:
# Tables in the database:
# genres
# title_basics
# title_genres
# title_ratings
# tmdb_data

# %%
# Create a session
Session = sessionmaker(bind=engine)
session = Session()

# %%
session.commit()
